# %% [markdown]
# # Collecting Steam Data from Official API
#
# Here is the API document

# %%
import requests

# %%
# example api request

sampleReq = requests.get(
    "http://api.steampowered.com/ISteamWebAPIUtil/GetSupportedAPIList/v1/")

sampleReq.json()
# Out:
# {'apilist': {'interfaces': [{'name': 'IClientStats_1046930',
#     'methods': [{'name': 'ReportEvent',
#       'version': 1,
#       'httpmethod': 'POST',
#       'parameters': []}]},
#    {'name': 'IGCVersion_1046930',
#     'methods': [{'name': 'GetClientVersion',
#       'version': 1,
#       'httpmethod': 'GET',
#       'parameters': []},
#      {'name': 'GetServerVersion',
#       'version': 1,
#       'httpmethod': 'GET',
#       'parameters': []}]},
#    {'name': 'IGCVersion_1269260',
#     'methods': [{'name': 'GetClientVersion',
#       'version': 1,
#       'httpmethod': 'GET',
#       'parameters': []},
#      {'name': 'GetServerVersion',
#       'version': 1,
#       'httpmethod': 'GET',
#       'parameters': []}]},
#    {'name': 'IGCVersion_440',
#     'methods': [{'name': 'GetClientVersion',
#       'version': 1,
#       'httpmethod': 'GET',
#       'parameters': []},
#      {'name': 'GetServerVersion',
#       'version': 1,
#       'httpmethod': 'GET',
# ...
